# %% [markdown]
# <a href="https://colab.research.google.com/github/Bemused5/mineria-de-datos/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mineria de Datos

# %% [markdown]
# ##Primer Parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# ### Conceptos

# %% [markdown]
# #### Ciencia de Datos

# %% [markdown]
# ##### La Ciencia de Datos es la disciplina que combina estadística, programación y análisis para transformar grandes volúmenes de datos en información útil, patrones y predicciones que ayudan a tomar mejores decisiones.

# %% [markdown]
# #### Mineria de Datos

# %% [markdown]
# ##### La Minería de Datos (Data Mining) es el proceso técnico de explorar grandes bases de datos de forma automática para descubrir patrones ocultos, correlaciones desconocidas y tendencias que no son visibles a simple vista.

# %% [markdown]
# ### Comandos de Ayuda en IPython

# %% [markdown]
# **help(objeto)**: Muestra la ayuda oficial de Python para ese objeto.

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# **objeto?**: Forma rápida de ver la documentación (docstring) y tipo del objeto. Sirve para funciones, listas, métodos, etc.

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %% [markdown]
# **objeto??**: Muestra el código fuente del objeto (si está escrito en Python). Si está en C, muestra lo mismo que ?.

# %%
def square(a):
    """Return the square of a."""
    return a ** 2

square??
# Out:
# Signature: square(a)
# Source:
# def square(a):
#     """Return the square of a."""
#     return a ** 2
# File:      /var/folders/3v/5mjcyc7j4750dgb_6qg_mzvr0000gn/T/ipykernel_8565/77688024.py
# Type:      function

# %% [markdown]
# **objeto.<TAB>**: Muestra una lista de todos los atributos y métodos públicos disponibles para ese objeto (autocompletado).

# %%
L = [1, 2, 3]
# Escribe L. y presiona TAB para ver opciones
# L.<TAB>

# %% [markdown]
# **objeto._<TAB>**: Muestra los métodos ocultos o privados (los que empiezan con _ o __).

# %%
# L._<TAB>

# %% [markdown]
# **from libreria import <TAB>**: Muestra qué funciones o clases puedes importar de esa librería.

# %%
# from itertools import <TAB>

# %% [markdown]
# **import <TAB>**: Muestra todas las librerías instaladas que puedes importar.

# %%
# import <TAB>

# %% [markdown]
# ***Texto?**: Busca todos los comandos que terminan con esa palabra.

# %%
*Warning?
# Out:
# BytesWarning
# DeprecationWarning
# EncodingWarning
# FutureWarning
# ImportWarning
# PendingDeprecationWarning
# ResourceWarning
# RuntimeWarning
# SyntaxWarning
# UnicodeWarning
# UserWarning
# Warning

# %% [markdown]
# **objeto.*texto*?**: Busca métodos dentro de un objeto que contengan esa palabra en cualquier parte.

# %%
str.*find*?
# Out:
# str.find
# str.rfind

# %% [markdown]
# #### IPython MAgic Commands

# %% [markdown]
# **%timeit**: Mide el tiempo de ejecución de una línea de código. Ejecuta el código múltiples veces y calcula estadísticas (promedio, desviación) para obtener mediciones precisas del rendimiento.

# %%
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 40.3 μs ± 952 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ##### Aqui quiero que añadas un comentario

# %%
# %%timeit
L = []
for n in range(1000):
    L.append(n ** 2)
# Out:
# 48.2 μs ± 1.19 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ##### Aqui quiero que añadas un comentario

# %%
# %timeit?
# Out:
# Docstring:
# Time execution of a Python statement or expression
#
# **Usage, in line mode**::
#
#   %timeit [-n<N> -r<R> [-t|-c] -q -p<P> [-o|-v <V>]] statement
#
# **or in cell mode**::
#
#   %%timeit [-n<N> -r<R> [-t|-c] -q -p<P> [-o|-v <V>]] setup_code
#   code
#   code...
#
# Time execution of a Python statement or expression using the timeit
# module.  This function can be used both as a line and cell magic:
#
# - In line mode you can time a single-line statement (though multiple
#   ones can be chained with using semicolons).
#
# - In cell mode, the statement in the first line is used as setup code
#   (executed but not timed) and the body of the cell is timed.  The cell
#   body has access to any variables created in the setup code.
#
# Options:
#
# -n<N>
#   Execute the given statement N times in a loop. If N is not
#   provided, N is determined so as to get sufficient accuracy.
#
# -r<R>
#   Number of repeats R, each consisting of N loops, and take the
#   average result.
# ...

# %% [markdown]
# #### Shell Commands in IPython

# %% [markdown]
# ##### Aqui quiero que añadas un comentario

# %%
# !ls
# Out:
# README.md       Untitled1.ipynb

# %% [markdown]
# ##### Aqui quiero que añadas un comentario

# %%
# !pwd
# Out:
# /Users/mausalinascarrillo/Documents/MineriaDatos/mineria-de-datos

# %% [markdown]
# ##### Aqui quiero que añadas un comentario

# %%
# !env
# Out:
# VSCODE_CRASH_REPORTER_PROCESS_TYPE=extensionHost
# SHELL=/bin/zsh
# TMPDIR=/var/folders/3v/5mjcyc7j4750dgb_6qg_mzvr0000gn/T/
# HOMEBREW_REPOSITORY=/opt/homebrew
# PYTHONUNBUFFERED=1
# ORIGINAL_XDG_CURRENT_DESKTOP=undefined
# MallocNanoZone=0
# PYTHONIOENCODING=utf-8
# USER=mausalinascarrillo
# COMMAND_MODE=unix2003
# SSH_AUTH_SOCK=/private/tmp/com.apple.launchd.74cViZ5k2w/Listeners
# __CF_USER_TEXT_ENCODING=0x1F5:0x0:0x56
# VIRTUAL_ENV=/Users/mausalinascarrillo/Documents/MineriaDatos/mineria-de-datos/.venv
# ELECTRON_RUN_AS_NODE=1
# ...

# %% [markdown]
# #### Understanding Data Types in Python with Numpy

# %%
int result = 0;
for(int i=0; i<100; i++){
    result += i;
}
# Out:
#   Cell In[34], line 1
#     int result = 0;
#         ^
# SyntaxError: invalid syntax
